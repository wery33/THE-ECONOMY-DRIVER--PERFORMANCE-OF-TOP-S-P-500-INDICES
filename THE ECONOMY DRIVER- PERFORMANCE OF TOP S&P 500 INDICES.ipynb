# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ticker = ["AAPL","MSFT","AMZN","NVDA", "GOOGL","TSLA","META"]

# %%
stocks = yf.download(ticker, start = "2010-01-1",  end = "2023-12-15")
# Out:
# [*********************100%%**********************]  7 of 7 completed

# %%
stocks.describe().T
# Out:
#                   count          mean           std           min  \
# Adj Close AAPL   3512.0  5.753123e+01  5.545394e+01  5.814175e+00
#           AMZN   3512.0  6.309143e+01  5.463570e+01  5.430500e+00
#           GOOGL  3512.0  5.386276e+01  3.889899e+01  1.091266e+01
#           META   2913.0  1.570295e+02  9.037022e+01  1.773000e+01
#           MSFT   3512.0  1.092326e+02  1.018329e+02  1.761333e+01
#           NVDA   3512.0  7.147875e+01  1.067357e+02  2.036506e+00
#           TSLA   3390.0  6.993384e+01  1.011404e+02  1.053333e+00
# Close     AAPL   3512.0  5.954281e+01  5.505500e+01  6.858929e+00
#           AMZN   3512.0  6.309143e+01  5.463570e+01  5.430500e+00
#           GOOGL  3512.0  5.386276e+01  3.889899e+01  1.091266e+01
#           META   2913.0  1.570295e+02  9.037022e+01  1.773000e+01
#           MSFT   3512.0  1.145586e+02  1.010437e+02  2.301000e+01
#           NVDA   3512.0  7.175797e+01  1.067023e+02  2.220000e+00
# ...

# %%
stocks.to_csv("stocksPAT.csv")

# %%
df = pd.read_csv("stocksPAT.csv")

# %%
df
# Out:
#       Unnamed: 0           Adj Close         Adj Close.1         Adj Close.2  \
# 0            NaN                AAPL                AMZN               GOOGL
# 1           Date                 NaN                 NaN                 NaN
# 2     2010-01-04   6.478997707366943   6.695000171661377  15.684433937072754
# 3     2010-01-05   6.490199565887451   6.734499931335449  15.615365028381348
# 4     2010-01-06   6.386965274810791   6.612500190734863  15.221721649169922
# ...          ...                 ...                 ...                 ...
# 3509  2023-12-08   195.7100067138672   147.4199981689453  134.99000549316406
# 3510  2023-12-11  193.17999267578125  145.88999938964844   133.2899932861328
# 3511  2023-12-12   194.7100067138672  147.47999572753906  132.52000427246094
# 3512  2023-12-13   197.9600067138672  148.83999633789062  132.57000732421875
# 3513  2023-12-14  198.11000061035156   147.4199981689453  131.94000244140625
#
# ...

# %%
stocks = pd.read_csv("stocksPAT.csv", header = [0,1], index_col = [0], parse_dates= [0])

# %%
stocks
# Out:
#              Adj Close                                                  \
#                   AAPL        AMZN       GOOGL        META        MSFT
# Date
# 2010-01-04    6.478998    6.695000   15.684434         NaN   23.474928
# 2010-01-05    6.490200    6.734500   15.615365         NaN   23.482500
# 2010-01-06    6.386965    6.612500   15.221722         NaN   23.338390
# 2010-01-07    6.375158    6.500000   14.867367         NaN   23.095686
# 2010-01-08    6.417542    6.676000   15.065566         NaN   23.254957
# ...                ...         ...         ...         ...         ...
# 2023-12-08  195.710007  147.419998  134.990005  332.750000  374.230011
# 2023-12-11  193.179993  145.889999  133.289993  325.279999  371.299988
# 2023-12-12  194.710007  147.479996  132.520004  334.220001  374.380005
# 2023-12-13  197.960007  148.839996  132.570007  334.739990  374.369995
# 2023-12-14  198.110001  147.419998  131.940002  333.170013  365.929993
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                                      \
#               AAPL         AMZN        GOOGL         META         MSFT
# count  3512.000000  3512.000000  3512.000000  2913.000000  3512.000000
# mean     57.531226    63.091434    53.862764   157.029471   109.232622
# std      55.453943    54.635702    38.898994    90.370219   101.832904
# min       5.814175     5.430500    10.912663    17.730000    17.613335
# 25%      17.037120    14.072625    21.923048    80.680000    27.380227
# 50%      29.069673    40.743750    40.832500   153.130005    57.115902
# 75%      86.422491    99.434626    73.207998   203.839996   190.359665
# max     198.110001   186.570496   149.838501   382.179993   382.700012
#
#                                        Close                            ...  \
#               NVDA         TSLA         AAPL         AMZN        GOOGL  ...
# count  3512.000000  3390.000000  3512.000000  3512.000000  3512.000000  ...
# ...

# %%
#Closing Prices

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close
# Out:
#                   AAPL        AMZN       GOOGL        META        MSFT  \
# Date
# 2010-01-04    7.643214    6.695000   15.684434         NaN   30.950001
# 2010-01-05    7.656429    6.734500   15.615365         NaN   30.959999
# 2010-01-06    7.534643    6.612500   15.221722         NaN   30.770000
# 2010-01-07    7.520714    6.500000   14.867367         NaN   30.450001
# 2010-01-08    7.570714    6.676000   15.065566         NaN   30.660000
# ...                ...         ...         ...         ...         ...
# 2023-12-08  195.710007  147.419998  134.990005  332.750000  374.230011
# 2023-12-11  193.179993  145.889999  133.289993  325.279999  371.299988
# 2023-12-12  194.710007  147.479996  132.520004  334.220001  374.380005
# 2023-12-13  197.960007  148.839996  132.570007  334.739990  374.369995
# 2023-12-14  198.110001  147.419998  131.940002  333.170013  365.929993
#
#                   NVDA        TSLA
# Date
# 2010-01-04    4.622500         NaN
# ...

# %%
# %matplotlib inline
plt.style.use("seaborn")
# Out:
# C:\Users\patrick\AppData\Local\Temp\ipykernel_16332\673233146.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
close.dropna(inplace = True)

# %%
close
# Out:
#                   AAPL        AMZN       GOOGL        META        MSFT  \
# Date
# 2012-05-18   18.942142   10.692500   15.025025   38.230000   29.270000
# 2012-05-21   20.045713   10.905500   15.368118   34.029999   29.750000
# 2012-05-22   19.891787   10.766500   15.035035   31.000000   29.760000
# 2012-05-23   20.377144   10.864000   15.251752   32.000000   29.110001
# 2012-05-24   20.190001   10.762000   15.106607   33.029999   29.070000
# ...                ...         ...         ...         ...         ...
# 2023-12-08  195.710007  147.419998  134.990005  332.750000  374.230011
# 2023-12-11  193.179993  145.889999  133.289993  325.279999  371.299988
# 2023-12-12  194.710007  147.479996  132.520004  334.220001  374.380005
# 2023-12-13  197.960007  148.839996  132.570007  334.739990  374.369995
# 2023-12-14  198.110001  147.419998  131.940002  333.170013  365.929993
#
#                   NVDA        TSLA
# Date
# 2012-05-18    3.020000    1.837333
# ...

# %%
close.plot(figsize=(15,8), fontsize = 12)
plt.legend(fontsize = 12)

# %%
stocks.plot(kind = 'hist', figsize=(12,8), bins = 100)
plt.show()

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose
# Out:
#                    AAPL         AMZN       GOOGL        META         MSFT  \
# Date
# 2012-05-18   100.000000   100.000000  100.000000  100.000000   100.000000
# 2012-05-21   105.826009   101.992053  102.283476   89.013861   101.639903
# 2012-05-22   105.013393   100.692077  100.066621   81.088152   101.674068
# 2012-05-23   107.575708   101.603930  101.508993   83.703898    99.453366
# 2012-05-24   106.587734   100.649988  100.542975   86.398115    99.316704
# ...                 ...          ...         ...         ...          ...
# 2023-12-08  1033.198894  1378.723372  898.434460  870.389757  1278.544602
# 2023-12-11  1019.842358  1364.414289  887.119922  850.850125  1268.534274
# 2023-12-12  1027.919660  1379.284491  881.995212  874.234908  1279.057052
# 2023-12-13  1045.077170  1392.003692  882.328010  875.595067  1279.022854
# 2023-12-14  1045.869023  1378.723372  878.134973  871.488405  1250.187861
#
#                     NVDA          TSLA
# Date
# ...

# %%
normclose.plot(figsize=(13,8), fontsize = 12 )
plt.legend(fontsize = 12)

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame or Series named 'close' with the closing prices for each stock

ticker = ["AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "TSLA", "META"]

# Assuming 'close' is a DataFrame with columns named after the tickers
close.plot(figsize=(15, 8), fontsize=12)

# Adding labels for each stock
for stock in ticker:
    plt.plot(close.index, close[stock], label=stock)

# Displaying the legend
plt.legend(fontsize=12)

# Adding labels and title
plt.xlabel("Date", fontsize=12)
plt.ylabel("Closing Price", fontsize=12)
plt.title("Closing Prices of Stocks", fontsize=14)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame or Series named 'close' with the closing prices for each stock

ticker = ["AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "TSLA", "META"]

# Assuming 'close' is a DataFrame with columns named after the tickers
ax = close.plot(figsize=(20, 15), fontsize=12)

# Adding labels for each stock
for stock in ticker:
    x = close.index[-1]  # Use the last date for annotation
    y = close[stock].iloc[-1]  # Get the closing price at the last date
    plt.text(x, y, stock, fontsize=12, ha='left', va='center')

# Adding labels and title
plt.xlabel("Date", fontsize=12)
plt.ylabel("Closing Price", fontsize=12)
plt.title("Closing Prices of Stocks", fontsize=14)

# Displaying the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame or Series named 'close' with the closing prices for each stock

ticker = ["AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "TSLA", "META"]

# Assuming 'close' is a DataFrame with columns named after the tickers
ax = normclose.plot(figsize=(15,10), fontsize=12)

# Adding labels for each stock
for stock in ticker:
    x = close.index[-1]  # Use the last date for annotation
    y = close[stock].iloc[-1]  # Get the closing price at the last date
    plt.text(x, y, stock, fontsize=12, ha='left', va='center')   

# Adding labels and title
plt.xlabel("Date", fontsize=12)
plt.ylabel("Closing Price", fontsize=12)
plt.title("Closing Prices of Stocks", fontsize=14)

# Displaying the plot
plt.show()

# %%
normclose.AAPL.plot(figsize=(13,8), fontsize = 12 )
plt.legend(fontsize = 12)

# %%
normclose.META.plot(figsize=(13,8), fontsize = 12 )
plt.legend(fontsize = 12)

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame or Series named 'normclose' with normalized closing prices for each stock

ticker = ["AAPL", "MSFT", "AMZN", "NVDA", "GOOGL", "TSLA", "META"]

# Assuming 'normclose' is a DataFrame with columns named after the tickers
ax = normclose.plot(figsize=(15, 10), fontsize=12)

# Adding labels for each stock
for stock in ticker:
    x = normclose.index[-1]  # Use the last date for annotation
    y = normclose[stock].iloc[-1]  # Get the normalized closing price at the last date
    plt.text(x, y, stock, fontsize=12, ha='left', va='center')

# Adding labels and title
plt.xlabel("Date", fontsize=12)
plt.ylabel("Normalized Closing Price", fontsize=12)
plt.title("Normalized Closing Prices of Stocks", fontsize=14)

# Displaying the plot
plt.show()

# %%
ret = close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL      AMZN     GOOGL      META      MSFT      NVDA  \
# Date
# 2012-05-21  0.058260  0.019921  0.022835 -0.109861  0.016399  0.017384
# 2012-05-22 -0.007679 -0.012746 -0.021674 -0.089039  0.000336 -0.012205
# 2012-05-23  0.024400  0.009056  0.014414  0.032258 -0.021841  0.024712
# 2012-05-24 -0.009184 -0.009389 -0.009517  0.032187 -0.001374 -0.026527
# 2012-05-25 -0.005360 -0.010918 -0.020094 -0.033909 -0.000344  0.023947
#
#                 TSLA
# Date
# 2012-05-21  0.043904
# 2012-05-22  0.070559
# 2012-05-23  0.007143
# 2012-05-24 -0.023855
# 2012-05-25 -0.015522

# %%
ret.describe()
# Out:
#               AAPL         AMZN        GOOGL         META         MSFT  \
# count  2912.000000  2912.000000  2912.000000  2912.000000  2912.000000
# mean      0.000968     0.001109     0.000892     0.001065     0.001009
# std       0.017934     0.020401     0.017097     0.025313     0.016794
# min      -0.128647    -0.140494    -0.116341    -0.263901    -0.147390
# 25%      -0.007565    -0.008749    -0.007127    -0.010059    -0.006954
# 50%       0.000871     0.000953     0.000779     0.000967     0.000695
# 75%       0.010320     0.011433     0.009236     0.012820     0.009476
# max       0.119808     0.141311     0.162584     0.296115     0.142169
#
#               NVDA         TSLA
# count  2912.000000  2912.000000
# mean      0.002128     0.002321
# std       0.027857     0.035621
# min      -0.187559    -0.210628
# 25%      -0.011091    -0.015221
# 50%       0.001924     0.001450
# 75%       0.015149     0.019245
# max       0.298067     0.243951

# %%
ret.describe().T
# Out:
#         count      mean       std       min       25%       50%       75%  \
# AAPL   2912.0  0.000968  0.017934 -0.128647 -0.007565  0.000871  0.010320
# AMZN   2912.0  0.001109  0.020401 -0.140494 -0.008749  0.000953  0.011433
# GOOGL  2912.0  0.000892  0.017097 -0.116341 -0.007127  0.000779  0.009236
# META   2912.0  0.001065  0.025313 -0.263901 -0.010059  0.000967  0.012820
# MSFT   2912.0  0.001009  0.016794 -0.147390 -0.006954  0.000695  0.009476
# NVDA   2912.0  0.002128  0.027857 -0.187559 -0.011091  0.001924  0.015149
# TSLA   2912.0  0.002321  0.035621 -0.210628 -0.015221  0.001450  0.019245
#
#             max
# AAPL   0.119808
# AMZN   0.141311
# GOOGL  0.162584
# META   0.296115
# MSFT   0.142169
# NVDA   0.298067
# TSLA   0.243951

# %%
# To select only two columns
summary = ret.describe().T.loc[:,['mean','std']]
summary
# Out:
#            mean       std
# AAPL   0.000968  0.017934
# AMZN   0.001109  0.020401
# GOOGL  0.000892  0.017097
# META   0.001065  0.025313
# MSFT   0.001009  0.016794
# NVDA   0.002128  0.027857
# TSLA   0.002321  0.035621

# %%
summary["mean"]= summary["mean"]*252
summary["std"]= summary["std"]*np.sqrt(252)
summary
# Out:
#            mean       std
# AAPL   0.243812  0.284698
# AMZN   0.279417  0.323850
# GOOGL  0.224771  0.271404
# META   0.268263  0.401837
# MSFT   0.254207  0.266599
# NVDA   0.536349  0.442221
# TSLA   0.584787  0.565464

# %%
summary.plot.scatter(x ="std", y = "mean", figsize =(10,8),fontsize = 12 )
for i in summary.index:
    plt.annotate(i, xy = (summary.loc[i, "std"]+0.002, summary.loc[i,"mean"]+0.002), size=10)
    plt.xlabel("Annual risk(std)", fontsize = 15)
    plt.ylabel("Annual returns", fontsize= 15)
    plt.title("Risk/Return", fontsize = 25)

# %%
ret
# Out:
#                 AAPL      AMZN     GOOGL      META      MSFT      NVDA  \
# Date
# 2012-05-21  0.058260  0.019921  0.022835 -0.109861  0.016399  0.017384
# 2012-05-22 -0.007679 -0.012746 -0.021674 -0.089039  0.000336 -0.012205
# 2012-05-23  0.024400  0.009056  0.014414  0.032258 -0.021841  0.024712
# 2012-05-24 -0.009184 -0.009389 -0.009517  0.032187 -0.001374 -0.026527
# 2012-05-25 -0.005360 -0.010918 -0.020094 -0.033909 -0.000344  0.023947
# ...              ...       ...       ...       ...       ...       ...
# 2023-12-08  0.007412  0.003676 -0.014168  0.018862  0.008842  0.019530
# 2023-12-11 -0.012927 -0.010379 -0.012594 -0.022449 -0.007829 -0.018503
# 2023-12-12  0.007920  0.010899 -0.005777  0.027484  0.008295  0.022090
# 2023-12-13  0.016691  0.009222  0.000377  0.001556 -0.000027  0.009044
# 2023-12-14  0.000758 -0.009540 -0.004752 -0.004690 -0.022545  0.005448
#
#                 TSLA
# Date
# 2012-05-21  0.043904
# 2012-05-22  0.070559
# 2012-05-23  0.007143
# ...

# %%
ret.cov()
# Out:
#            AAPL      AMZN     GOOGL      META      MSFT      NVDA      TSLA
# AAPL   0.000322  0.000181  0.000171  0.000199  0.000183  0.000258  0.000237
# AMZN   0.000181  0.000416  0.000217  0.000258  0.000202  0.000276  0.000267
# GOOGL  0.000171  0.000217  0.000292  0.000237  0.000192  0.000252  0.000216
# META   0.000199  0.000258  0.000237  0.000641  0.000199  0.000297  0.000260
# MSFT   0.000183  0.000202  0.000192  0.000199  0.000282  0.000275  0.000220
# NVDA   0.000258  0.000276  0.000252  0.000297  0.000275  0.000776  0.000382
# TSLA   0.000237  0.000267  0.000216  0.000260  0.000220  0.000382  0.001269

# %%
ret.cov()
# Out:
#            AAPL      AMZN     GOOGL      META      MSFT      NVDA      TSLA
# AAPL   0.000322  0.000181  0.000171  0.000199  0.000183  0.000258  0.000237
# AMZN   0.000181  0.000416  0.000217  0.000258  0.000202  0.000276  0.000267
# GOOGL  0.000171  0.000217  0.000292  0.000237  0.000192  0.000252  0.000216
# META   0.000199  0.000258  0.000237  0.000641  0.000199  0.000297  0.000260
# MSFT   0.000183  0.000202  0.000192  0.000199  0.000282  0.000275  0.000220
# NVDA   0.000258  0.000276  0.000252  0.000297  0.000275  0.000776  0.000382
# TSLA   0.000237  0.000267  0.000216  0.000260  0.000220  0.000382  0.001269

# %% [markdown]
# ##### Covariance is a measure of the relationship between two random variables and to what extent, they change together. Or we can say, in other words, it defines the changes between the two variables, such that change in one variable is equal to change in another variable.

# %%
plt.figure(figsize=(12, 5))
sns.set(font_scale=1.0)
sns.heatmap(ret.corr(), cmap="Reds", annot=True, annot_kws={"size": 15}, vmax=0.6)
plt.show()
